# %%
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv
# %matplotlib inline

# %%
img = io.imread('mixco_1_and_ebenezer_ortho-cog.tif')
img1= img[:,:,:3]

# %%
(img.shape,img1.shape)
# Out:
# ((27604, 26641, 4), (27604, 26641, 3))

# %%
img2=img1[:10000,:10000,:]
img2.shape
# img3=img1[:100,:100,:]
# img3.shape
# Out:
# (100, 100, 3)

# %%
io.imsave("output2.png",img2)

# %%
X=cv.imread("output2.png")

# %%
plt.imshow(X)
plt.show()
